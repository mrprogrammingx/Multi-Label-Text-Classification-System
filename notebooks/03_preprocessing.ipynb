# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root / "src"))

import pandas as pd

from member3_preprocess import clean_text, preprocess_dataframe, show_examples

# %%
df = pd.DataFrame({
  "comment_text": [
    "HELLO!!! Visit https://example.com",
    "<b>Something</b>"
    "",
    None,
    "Text with 123 numbers!!!"
  ]
})

# %%
show_examples(df)
# Out:
# Before: HELLO!!! Visit https://example.com
# After: hello visit
# ----------------------------------------
# Before: <b>Something</b>
# After: something
# ----------------------------------------
# Before: None
# After:
# ----------------------------------------
# Before: Text with 123 numbers!!!
# After: text with numbers
# ----------------------------------------

# %%
cleaned_df = preprocess_dataframe(df)
cleaned_df
# Out:
# Removed empty rows: 1
#                          comment_text       cleaned_text
# 0  HELLO!!! Visit https://example.com        hello visit
# 1                    <b>Something</b>          something
# 2            Text with 123 numbers!!!  text with numbers
